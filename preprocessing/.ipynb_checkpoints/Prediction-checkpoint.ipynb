# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
import pmdarima as pm
from pmdarima.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv('training_data.csv')

# %% [markdown]
# Let's print the autocorrelation for the time series lags:

# %%
autocorrelation_plot(df['Close'])
plt.show()

# %% [markdown]
# We can see there is a positive correlation with the first 100 lags that is about 14 days (or 3 weeks). It may be benefitial to train with daily data or even weekly data to minimise the training cost. Depending on the period of prediction we are going to make, we initiate the model with the most significant lags.

# %%
# Split the data into training and test sets
train, test = train_test_split(df, train_size=0.9)

# %%
# Fit auto_arima
model = pm.auto_arima(train['Close'], max_p=14, max_d=2, max_q=5, trace=True, error_action='ignore', suppress_warnings=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.99 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-8655.998, Time=0.19 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=-9080.836, Time=0.27 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=-9271.952, Time=0.20 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=-9389.913, Time=0.27 sec
#  ARIMA(4,2,0)(0,0,0)[0]             : AIC=-9447.137, Time=0.35 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=-9485.433, Time=0.18 sec
#  ARIMA(6,2,0)(0,0,0)[0]             : AIC=-9543.681, Time=1.01 sec
#  ARIMA(7,2,0)(0,0,0)[0]             : AIC=-9561.254, Time=1.01 sec
#  ARIMA(8,2,0)(0,0,0)[0]             : AIC=-9569.118, Time=0.83 sec
#  ARIMA(9,2,0)(0,0,0)[0]             : AIC=-9568.861, Time=0.62 sec
#  ARIMA(8,2,1)(0,0,0)[0]             : AIC=-9594.581, Time=2.65 sec
#  ARIMA(7,2,1)(0,0,0)[0]             : AIC=-9592.425, Time=1.98 sec
#  ARIMA(9,2,1)(0,0,0)[0]             : AIC=-9597.077, Time=2.94 sec
#  ARIMA(10,2,1)(0,0,0)[0]             : AIC=-9615.980, Time=3.20 sec
#  ARIMA(10,2,0)(0,0,0)[0]             : AIC=-9581.251, Time=0.87 sec
#  ARIMA(11,2,1)(0,0,0)[0]             : AIC=-9618.406, Time=3.83 sec
#  ARIMA(11,2,0)(0,0,0)[0]             : AIC=-9588.633, Time=1.05 sec
#  ARIMA(12,2,1)(0,0,0)[0]             : AIC=-9618.613, Time=4.24 sec
#  ARIMA(12,2,0)(0,0,0)[0]             : AIC=-9605.745, Time=1.29 sec
#  ARIMA(13,2,1)(0,0,0)[0]             : AIC=-9601.622, Time=4.90 sec
#  ARIMA(12,2,2)(0,0,0)[0]             : AIC=-9689.233, Time=4.42 sec
#  ARIMA(11,2,2)(0,0,0)[0]             : AIC=-9559.151, Time=3.97 sec
#  ARIMA(13,2,2)(0,0,0)[0]             : AIC=-9690.699, Time=3.81 sec
#  ARIMA(14,2,2)(0,0,0)[0]             : AIC=inf, Time=6.06 sec
#  ARIMA(13,2,3)(0,0,0)[0]             : AIC=-9615.048, Time=5.43 sec
#  ARIMA(12,2,3)(0,0,0)[0]             : AIC=-9694.768, Time=5.50 sec
#  ARIMA(11,2,3)(0,0,0)[0]             : AIC=-9682.966, Time=4.52 sec
#  ARIMA(12,2,4)(0,0,0)[0]             : AIC=-9692.611, Time=5.17 sec
#  ARIMA(11,2,4)(0,0,0)[0]             : AIC=-9646.711, Time=4.72 sec
#  ARIMA(13,2,4)(0,0,0)[0]             : AIC=-9688.298, Time=3.92 sec
#  ARIMA(12,2,3)(0,0,0)[0] intercept   : AIC=-9563.399, Time=5.80 sec
#
# Best model:  ARIMA(12,2,3)(0,0,0)[0]
# Total fit time: 86.488 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1574
# Model:              SARIMAX(12, 2, 3)   Log Likelihood                4863.384
# Date:                Tue, 23 Apr 2024   AIC                          -9694.768
# Time:                        15:11:27   BIC                          -9609.006
# Sample:                             0   HQIC                         -9662.894
#                                - 1574
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3435      1.184     -0.290      0.772      -2.664       1.977
# ar.L2         -0.1090      1.089     -0.100      0.920      -2.243       2.025
# ar.L3         -0.0045      0.038     -0.119      0.905      -0.079       0.070
# ar.L4          0.0202      0.039      0.516      0.606      -0.057       0.097
# ar.L5          0.0051      0.044      0.117      0.907      -0.081       0.092
# ar.L6         -0.0047      0.039     -0.119      0.905      -0.082       0.073
# ar.L7          0.0580      0.022      2.635      0.008       0.015       0.101
# ar.L8          0.0175      0.074      0.235      0.814      -0.128       0.163
# ar.L9         -0.0185      0.073     -0.253      0.800      -0.161       0.124
# ar.L10        -0.0764      0.046     -1.671      0.095      -0.166       0.013
# ar.L11        -0.0319      0.098     -0.325      0.745      -0.224       0.160
# ar.L12        -0.0290      0.077     -0.378      0.706      -0.180       0.122
# ma.L1         -0.6330      1.186     -0.534      0.594      -2.958       1.692
# ma.L2         -0.2505      0.959     -0.261      0.794      -2.131       1.630
# ma.L3         -0.0913      1.077     -0.085      0.932      -2.201       2.019
# sigma2         0.0001   1.71e-06     70.164      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             10064.21
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                            -0.66
# Prob(H) (two-sided):                  0.87   Kurtosis:                        15.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# We make the prediction and calculate the Root Mean Square Error:

# %%
# Make predictions
forecast, conf_int = model.predict(n_periods=len(test['Close']), return_conf_int=True)

for idx in forecast.index:
    yhat = forecast.loc[idx]
    obs = test['Close'].loc[idx]
    print(f'predicted={yhat}, expected={obs}')

rmse = sqrt(mean_squared_error(test['Close'], forecast))
print('Test RMSE: %.3f' % rmse)
# Out:
# predicted=5.095771026686972, expected=5.142540329314402
# predicted=5.094700736667703, expected=5.157214483399269
# predicted=5.0917046283236465, expected=5.152192710938209
# predicted=5.0898666866086275, expected=5.152250632793872
# predicted=5.088053858529417, expected=5.159973824658007
# predicted=5.0871539393747875, expected=5.159916961764547
# predicted=5.085331355099906, expected=5.15871042619753
# predicted=5.0833004865302325, expected=5.132026630430481
# predicted=5.081060036756688, expected=5.146097588561642
# predicted=5.078896425315239, expected=5.147145592945473
# predicted=5.077106058088222, expected=5.145897861018487
# predicted=5.075336307223653, expected=5.144174977295135
# predicted=5.073797249994349, expected=5.142949286443782
# predicted=5.072096120076985, expected=5.143474766490973
# predicted=5.0704062840469915, expected=5.142365036239715
# predicted=5.068628245637492, expected=5.151266388484042
# predicted=5.066928357910141, expected=5.14700012956336
# predicted=5.06525474268771, expected=5.15300251773786
# predicted=5.063618009595846, expected=5.158307865456576
# predicted=5.061978130145984, expected=5.166955076192539
# predicted=5.060305604178255, expected=5.16894870189411
# predicted=5.058623673277324, expected=5.165088749650398
# predicted=5.05691801504612, expected=5.165243022781083
# predicted=5.055228905359995, expected=5.160548405280335
# predicted=5.053538023441145, expected=5.155425194418204
# predicted=5.0518579485847805, expected=5.148947529989503
# predicted=5.050170392434098, expected=5.153840583779648
# predicted=5.048479919551063, expected=5.151961254915873
# predicted=5.046784394718557, expected=5.131795145037063
# predicted=5.04508845289955, expected=5.1397611811848645
# predicted=5.043395376943327, expected=5.132085642073765
# predicted=4.813467625968726, expected=4.9918940784010895
# predicted=4.811776982163876, expected=4.990568661006347
# predicted=4.810086338359025, expected=4.950461258159202
# predicted=4.808395694554175, expected=4.9428174217246585
# predicted=4.806705050749325, expected=4.956771689111921
# predicted=4.8050144069444745, expected=4.957023511768274
# predicted=4.803323763139624, expected=4.955066192801655
# predicted=4.801633119334774, expected=4.958288856600868
# predicted=4.799942475529924, expected=4.956038294298351
# Test RMSE: 0.184

# %%
# Plot the results

plt.figure(figsize=(12, 6))
plt.plot(train['Close'], label='Training Data')
plt.plot(test['Close'], label='Test Data')
plt.plot(forecast, label='Forecast', color='green')
plt.fill_between(test.index, conf_int[:, 0], conf_int[:, 1], color='gray', alpha=0.2)
plt.title('ARIMA Forecast')
plt.xlabel('Index')
plt.ylabel('Close Price')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# From the above graph, we can see the test set falls inside the area of the prediction model with 95% confidence.

# %%
model2 = pm.auto_arima(df['Close'], max_p=14, max_d=2, max_q=5, trace=True, error_action='ignore', suppress_warnings=True)
# Make predictions for the next 10 days
forecast_next_10_days, conf_int_next_10_days = model2.predict(n_periods=70, return_conf_int=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=1.43 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=-9556.280, Time=0.08 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=-10029.380, Time=0.08 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=-10251.609, Time=0.22 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=-10384.354, Time=0.31 sec
#  ARIMA(4,2,0)(0,0,0)[0]             : AIC=-10448.406, Time=0.28 sec
#  ARIMA(5,2,0)(0,0,0)[0]             : AIC=-10483.909, Time=1.08 sec
#  ARIMA(6,2,0)(0,0,0)[0]             : AIC=-10556.362, Time=0.64 sec
#  ARIMA(7,2,0)(0,0,0)[0]             : AIC=-10575.953, Time=1.41 sec
#  ARIMA(8,2,0)(0,0,0)[0]             : AIC=-10586.268, Time=0.43 sec
#  ARIMA(9,2,0)(0,0,0)[0]             : AIC=-10586.066, Time=1.19 sec
#  ARIMA(8,2,1)(0,0,0)[0]             : AIC=-10616.007, Time=2.90 sec
#  ARIMA(7,2,1)(0,0,0)[0]             : AIC=-10624.787, Time=2.31 sec
#  ARIMA(6,2,1)(0,0,0)[0]             : AIC=-10612.145, Time=1.77 sec
#  ARIMA(7,2,2)(0,0,0)[0]             : AIC=-10713.363, Time=2.55 sec
#  ARIMA(6,2,2)(0,0,0)[0]             : AIC=inf, Time=2.06 sec
#  ARIMA(8,2,2)(0,0,0)[0]             : AIC=inf, Time=3.12 sec
#  ARIMA(7,2,3)(0,0,0)[0]             : AIC=inf, Time=2.86 sec
#  ARIMA(6,2,3)(0,0,0)[0]             : AIC=inf, Time=2.85 sec
#  ARIMA(8,2,3)(0,0,0)[0]             : AIC=inf, Time=3.51 sec
#  ARIMA(7,2,2)(0,0,0)[0] intercept   : AIC=-10594.958, Time=1.19 sec
#
# Best model:  ARIMA(7,2,2)(0,0,0)[0]
# Total fit time: 32.535 seconds

# %%
# Plot the results
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df.index, np.exp(df['Close']), label='Training Data')
plt.plot(forecast_next_10_days.index, np.exp(forecast_next_10_days), label='Forecast', color='green')
plt.fill_between(forecast_next_10_days.index, np.exp(conf_int_next_10_days[:, 0]), np.exp(conf_int_next_10_days[:, 1]), color='gray', alpha=0.2)
plt.title('ARIMA Forecast')
plt.xlabel('Index')
plt.ylabel('Close Price')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Finally, I want to see the highest price of Tesla it may have to see if it worths investing in.

# %%
np.exp(conf_int_next_10_days[69:, 1])
# Out:
# array([175.02650183])
